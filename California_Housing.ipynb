# %%
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
housing = fetch_california_housing()

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(housing.data, housing.target)

# %%
X_train, X_valid, y_train, y_valid = train_test_split(X_train_full, y_train_full)

# %%
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
print("X_valid shape:", X_valid.shape)
print("y_valid shape:", y_valid.shape)
print("X_test shape:", X_test.shape)
print("y_test shape:", y_test.shape)
# Out:
# X_train shape: (11610, 8)
# y_train shape: (11610,)
# X_valid shape: (3870, 8)
# y_valid shape: (3870,)
# X_test shape: (5160, 8)
# y_test shape: (5160,)

# %%
X_train.shape[1:]
# Out:
# (8,)

# %%
# Scale the data

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_valid = scaler.transform(X_valid)
X_test = scaler.transform(X_test)

# %%
model = Sequential([
    Dense(30, activation='relu', input_shape=X_train.shape[1:]),
    Dense(1)
])

# %%
model.compile(
    loss='mse',
    optimizer='sgd'
)

# %%
history = model.fit(X_train, y_train, epochs=30,
                   validation_data=(X_valid, y_valid))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/30
# 11610/11610 [==============================] - 2s 141us/sample - loss: 0.8691 - val_loss: 0.5931
# Epoch 2/30
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.5512 - val_loss: 0.5139
# Epoch 3/30
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4989 - val_loss: 0.6398
# Epoch 4/30
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.7866 - val_loss: 0.4901
# Epoch 5/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4595 - val_loss: 0.4369
# Epoch 6/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4353 - val_loss: 0.4248
# Epoch 7/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4199 - val_loss: 0.4146
# Epoch 8/30
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4112 - val_loss: 0.4145
# Epoch 9/30
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.4089 - val_loss: 0.4061
# Epoch 10/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.4041 - val_loss: 0.4010
# Epoch 11/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3921 - val_loss: 0.3923
# Epoch 12/30
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3872 - val_loss: 0.3919
# Epoch 13/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3972 - val_loss: 0.3875
# Epoch 14/30
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3921 - val_loss: 0.3866
# Epoch 15/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3811 - val_loss: 0.3808
# Epoch 16/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3801 - val_loss: 0.3794
# Epoch 17/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3755 - val_loss: 0.3770
# Epoch 18/30
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3753 - val_loss: 0.3773
# Epoch 19/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3702 - val_loss: 0.3745
# Epoch 20/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3677 - val_loss: 0.3742
# Epoch 21/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3655 - val_loss: 0.3700
# Epoch 22/30
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.3627 - val_loss: 0.3725
# Epoch 23/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3622 - val_loss: 0.3719
# Epoch 24/30
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.3608 - val_loss: 0.3661
# Epoch 25/30
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3580 - val_loss: 0.3592
# Epoch 26/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3585 - val_loss: 0.3652
# Epoch 27/30
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3723 - val_loss: 0.3770
# Epoch 28/30
# 11610/11610 [==============================] - 1s 80us/sample - loss: 0.4436 - val_loss: 0.3835
# Epoch 29/30
# 11610/11610 [==============================] - 1s 82us/sample - loss: 0.3612 - val_loss: 0.3690
# Epoch 30/30
# 11610/11610 [==============================] - 1s 76us/sample - loss: 0.3614 - val_loss: 0.3609

# %%
mse_test = model.evaluate(X_test, y_test, verbose=1)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
mse_test
# Out:
# 0.3668902972871943

# %%
X_new = X_test[:3]

# %%
y_pred = model.predict(X_new)
y_pred
# Out:
# array([[2.1358058],
#        [3.187997 ],
#        [1.4991131]], dtype=float32)

# %%
# Build the a model with functional API

input_ = keras.layers.Input(shape=X_train.shape[1:])
hidden1 = keras.layers.Dense(30, activation='relu')(input_)
hidden2 = keras.layers.Dense(30, activation='relu')(hidden1)
concat = keras.layers.Concatenate()([input_, hidden2])
output = keras.layers.Dense(1)(concat)
model_func = keras.Model(inputs=[input_], outputs=[output])

# %%
model_func.compile(
    loss='mse',
    optimizer='sgd'
)

# %%
history_func = model_func.fit(X_train, y_train, epochs=30,
                   validation_data=(X_valid, y_valid))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/30
# 11610/11610 [==============================] - 2s 177us/sample - loss: 1.8652 - val_loss: 1.1419
# Epoch 2/30
# 11610/11610 [==============================] - 1s 91us/sample - loss: 2.6162 - val_loss: 1.0373
# Epoch 3/30
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.5131 - val_loss: 0.4491
# Epoch 4/30
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.4434 - val_loss: 0.4427
# Epoch 5/30
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.5290 - val_loss: 0.4320
# Epoch 6/30
# 11610/11610 [==============================] - 1s 103us/sample - loss: 0.4302 - val_loss: 0.4070
# Epoch 7/30
# 11610/11610 [==============================] - 1s 95us/sample - loss: 0.3981 - val_loss: 0.4018
# Epoch 8/30
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.4408 - val_loss: 0.3903
# Epoch 9/30
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.3975 - val_loss: 0.3744
# Epoch 10/30
# 11610/11610 [==============================] - 1s 94us/sample - loss: 0.3745 - val_loss: 0.3801
# Epoch 11/30
# 11610/11610 [==============================] - 1s 94us/sample - loss: 0.3780 - val_loss: 0.3679
# Epoch 12/30
# 11610/11610 [==============================] - 1s 116us/sample - loss: 0.3660 - val_loss: 0.3814
# Epoch 13/30
# 11610/11610 [==============================] - 1s 94us/sample - loss: 0.3634 - val_loss: 0.3821
# Epoch 14/30
# 11610/11610 [==============================] - 1s 98us/sample - loss: 0.3603 - val_loss: 0.3558
# Epoch 15/30
# 11610/11610 [==============================] - 1s 100us/sample - loss: 0.3642 - val_loss: 0.4260
# Epoch 16/30
# 11610/11610 [==============================] - 1s 105us/sample - loss: 0.3662 - val_loss: 0.4036
# Epoch 17/30
# 11610/11610 [==============================] - 1s 93us/sample - loss: 0.3574 - val_loss: 0.3774
# Epoch 18/30
# 11610/11610 [==============================] - 1s 93us/sample - loss: 0.3526 - val_loss: 0.3590
# Epoch 19/30
# 11610/11610 [==============================] - 1s 107us/sample - loss: 0.4485 - val_loss: 0.3432
# Epoch 20/30
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.3536 - val_loss: 0.3383
# Epoch 21/30
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.3363 - val_loss: 0.3564
# Epoch 22/30
# 11610/11610 [==============================] - 1s 98us/sample - loss: 0.4538 - val_loss: 0.3474
# Epoch 23/30
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.3349 - val_loss: 0.3503
# Epoch 24/30
# 11610/11610 [==============================] - 1s 97us/sample - loss: 0.3356 - val_loss: 0.3604
# Epoch 25/30
# 11610/11610 [==============================] - 1s 93us/sample - loss: 0.3343 - val_loss: 0.3509
# Epoch 26/30
# 11610/11610 [==============================] - 1s 98us/sample - loss: 0.3988 - val_loss: 0.3370
# Epoch 27/30
# 11610/11610 [==============================] - 1s 95us/sample - loss: 0.3393 - val_loss: 0.3439
# Epoch 28/30
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.3288 - val_loss: 0.3330
# Epoch 29/30
# 11610/11610 [==============================] - 1s 94us/sample - loss: 0.3200 - val_loss: 0.3582
# Epoch 30/30
# 11610/11610 [==============================] - 1s 93us/sample - loss: 0.4061 - val_loss: 0.3270

# %%
input_a = keras.layers.Input(shape=[5], name='wide_input')
input_b = keras.layers.Input(shape=[6], name='deep_input')
hidden1 = keras.layers.Dense(30, activation='relu')(input_b)
hidden2 = keras.layers.Dense(30, activation='relu')(hidden1)
concat = keras.layers.Concatenate()([input_a, hidden2])
output = keras.layers.Dense(1)(concat)
model_func_two_inp = keras.Model(inputs=[input_a, input_b], outputs=[output])

# %%
model_func_two_inp.compile(
    loss='mse',
    optimizer='sgd'
)

# %%
X_train_a, X_train_b = X_train[:,:5], X_train[:,2:]
X_valid_a, X_valid_b = X_valid[:,:5], X_valid[:,2:]
X_test_a, X_test_b = X_test[:,:5], X_test[:,2:]
X_new_a, X_new_b = X_test_a[:3], X_test_b[:3]

# %%
history_func_two_inp = model_func_two_inp.fit([X_train_a,X_train_b], y_train, epochs=30,
                   validation_data=([X_valid_a,X_valid_b], y_valid))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/30
# 11610/11610 [==============================] - 2s 147us/sample - loss: 0.9766 - val_loss: 0.6175
# Epoch 2/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.5889 - val_loss: 0.5396
# Epoch 3/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.5338 - val_loss: 0.5061
# Epoch 4/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.4897 - val_loss: 0.4860
# Epoch 5/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.4757 - val_loss: 0.4754
# Epoch 6/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.4616 - val_loss: 0.4494
# Epoch 7/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.4492 - val_loss: 0.4371
# Epoch 8/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.4396 - val_loss: 0.4366
# Epoch 9/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.4287 - val_loss: 0.4205
# Epoch 10/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.4209 - val_loss: 0.4160
# Epoch 11/30
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.4107 - val_loss: 0.4120
# Epoch 12/30
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.3998 - val_loss: 0.3950
# Epoch 13/30
# 11610/11610 [==============================] - 1s 87us/sample - loss: 0.3939 - val_loss: 0.3928
# Epoch 14/30
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.3857 - val_loss: 0.3835
# Epoch 15/30
# 11610/11610 [==============================] - 1s 87us/sample - loss: 0.3791 - val_loss: 0.3767
# Epoch 16/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.3767 - val_loss: 0.3807
# Epoch 17/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.3756 - val_loss: 0.3660
# Epoch 18/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.3631 - val_loss: 0.3593
# Epoch 19/30
# 11610/11610 [==============================] - 1s 94us/sample - loss: 0.3591 - val_loss: 0.3564
# Epoch 20/30
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.3551 - val_loss: 0.3575
# Epoch 21/30
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.3528 - val_loss: 0.3677
# Epoch 22/30
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.3501 - val_loss: 0.3483
# Epoch 23/30
# 11610/11610 [==============================] - 1s 87us/sample - loss: 0.3489 - val_loss: 0.3551
# Epoch 24/30
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.3446 - val_loss: 0.3548
# Epoch 25/30
# 11610/11610 [==============================] - 1s 87us/sample - loss: 0.3444 - val_loss: 0.3574
# Epoch 26/30
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.3426 - val_loss: 0.3617
# Epoch 27/30
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.3444 - val_loss: 0.3644
# Epoch 28/30
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.3433 - val_loss: 0.3502
# Epoch 29/30
# 11610/11610 [==============================] - 1s 89us/sample - loss: 0.3449 - val_loss: 0.3502
# Epoch 30/30
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.3489 - val_loss: 0.3450

# %%
mse_test = model_func_two_inp.evaluate((X_test_a,X_test_b), y_test)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
y_pred = model_func_two_inp.predict((X_new_a, X_new_b))
y_pred
# Out:
# array([[1.8158573],
#        [2.6385143],
#        [1.6500114]], dtype=float32)

# %%
# Two inputs and two outputs

input_a = keras.layers.Input(shape=[5], name='wide_input')
input_b = keras.layers.Input(shape=[6], name='deep_input')
hidden1 = keras.layers.Dense(30, activation='relu')(input_b)
hidden2 = keras.layers.Dense(30, activation='relu')(hidden1)
concat = keras.layers.Concatenate()([input_a, hidden2])
aux_output = keras.layers.Dense(1, name='aux_output')(hidden2)
output = keras.layers.Dense(1, name='main_output')(concat)
model_func_two_inp_two_out = keras.Model(inputs=[input_a, input_b], outputs=[output, aux_output])

# %%
model_func_two_inp_two_out.compile(
    loss=['mse','mse'],
    loss_weights=[0.9, 0.1],
    optimizer='sgd'
)

# %%
history_func_two_inp_two_out = model_func_two_inp_two_out.fit([X_train_a,X_train_b], (y_train,y_train), epochs=30,
                   validation_data=([X_valid_a,X_valid_b], (y_valid,y_valid)))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/30
# 11610/11610 [==============================] - 2s 200us/sample - loss: 0.9695 - main_output_loss: 0.8828 - aux_output_loss: 1.7486 - val_loss: 0.6650 - val_main_output_loss: 0.6019 - val_aux_output_loss: 1.2329
# Epoch 2/30
# 11610/11610 [==============================] - 1s 100us/sample - loss: 0.6350 - main_output_loss: 0.5806 - aux_output_loss: 1.1241 - val_loss: 0.5850 - val_main_output_loss: 0.5313 - val_aux_output_loss: 1.0678
# Epoch 3/30
# 11610/11610 [==============================] - 1s 100us/sample - loss: 0.5642 - main_output_loss: 0.5174 - aux_output_loss: 0.9857 - val_loss: 0.5684 - val_main_output_loss: 0.5235 - val_aux_output_loss: 0.9717
# Epoch 4/30
# 11610/11610 [==============================] - 1s 104us/sample - loss: 0.5408 - main_output_loss: 0.5020 - aux_output_loss: 0.8890 - val_loss: 0.5260 - val_main_output_loss: 0.4893 - val_aux_output_loss: 0.8551
# Epoch 5/30
# 11610/11610 [==============================] - 1s 104us/sample - loss: 0
# 11610/11610 [==============================] - 1s 105us/sample - loss: 0.3804 - main_output_loss: 0.3673 - aux_output_loss: 0.4989 - val_loss: 0.3926 - val_main_output_loss: 0.3803 - val_aux_output_loss: 0.5043
# Epoch 22/30
# 11610/11610 [==============================] - 1s 106us/sample - loss: 0.3776 - main_output_loss: 0.3650 - aux_output_loss: 0.4910 - val_loss: 0.3812 - val_main_output_loss: 0.3683 - val_aux_output_loss: 0.4976
# Epoch 23/30
# 11610/11610 [==============================] - 1s 104us/sample - loss: 0.3742 - main_output_loss: 0.3619 - aux_output_loss: 0.4849 - val_loss: 0.3755 - val_main_output_loss: 0.3631 - val_aux_output_loss: 0.4870
# Epoch 24/30
# 11610/11610 [==============================] - 1s 103us/sample - loss: 0.3734 - main_output_loss: 0.3616 - aux_output_loss: 0.4803 - val_loss: 0.3719 - val_main_output_loss: 0.3592 - val_aux_output_loss: 0.4872
# Epoch 25/30
# 11610/11610 [==============================] - 1s 102us/sample - loss: 0.3642 - main_output_loss: 0.3523 - aux_output_loss: 0.4710 - val_loss: 0.3691 - val_main_output_loss: 0.3570 - val_aux_output_loss: 0.4784
# Epoch 26/30
# 11610/11610 [==============================] - 1s 117us/sample - loss: 0.3593 - main_output_loss: 0.3474 - aux_output_loss: 0.4657 - val_loss: 0.3740 - val_main_output_loss: 0.3622 - val_aux_output_loss: 0.4809
# Epoch 27/30
# 11610/11610 [==============================] - 1s 106us/sample - loss: 0.3597 - main_output_loss: 0.3484 - aux_output_loss: 0.4609 - val_loss: 0.3821 - val_main_output_loss: 0.3698 - val_aux_output_loss: 0.4929
# Epoch 28/30
# 11610/11610 [==============================] - 1s 104us/sample - loss: 0.3571 - main_output_loss: 0.3463 - aux_output_loss: 0.4545 - val_loss: 0.3612 - val_main_output_loss: 0.3500 - val_aux_output_loss: 0.4620
# Epoch 29/30
# 11610/11610 [==============================] - 1s 112us/sample - loss: 0.3548 - main_output_loss: 0.3443 - aux_output_loss: 0.4494 - val_loss: 0.3603 - val_main_output_loss: 0.3493 - val_aux_output_loss: 0.4596
# Epoch 30/30
# 11610/11610 [==============================] - 1s 108us/sample - loss: 0.3540 - main_output_loss: 0.3438 - aux_output_loss: 0.4448 - val_loss: 0.3701 - val_main_output_loss: 0.3589 - val_aux_output_loss: 0.4716

# %%
total_loss, main_loss, aux_loss = model_func_two_inp_two_out.evaluate([X_test_a,X_test_b],[y_test,y_test])
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...

# %%
total_loss
# Out:
# 0.3693515338176905

# %%
main_loss
# Out:
# 0.35901904

# %%
aux_loss
# Out:
# 0.47627956

# %%
y_pred_main, y_pred_aux = model_func_two_inp_two_out.predict([X_new_a, X_new_b])

# %%
y_pred_main
# Out:
# array([[1.8107915],
#        [2.5969338],
#        [1.5181621]], dtype=float32)

# %%
y_pred_aux
# Out:
# array([[2.000983 ],
#        [2.4974527],
#        [1.6183124]], dtype=float32)

# %%
model_func_two_inp_two_out.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# deep_input (InputLayer)         [(None, 6)]          0
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 30)           210         deep_input[0][0]
# __________________________________________________________________________________________________
# wide_input (InputLayer)         [(None, 5)]          0
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 30)           930         dense_11[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 35)           0           wide_input[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 1)            36          concatenate_3[0][0]
# __________________________________________________________________________________________________
# aux_output (Dense)              (None, 1)            31          dense_12[0][0]
# ==================================================================================================
# Total params: 1,207
# Trainable params: 1,207
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# Create a model using Subclassing API

class Mymodel(tf.keras.Model):
    def __init__(self, units=30, activation='relu', **kwargs):
        super().__init__(**kwargs)
        self.hidden1 = keras.layers.Dense(units, activation=activation)
        self.hidden2 = keras.layers.Dense(units, activation=activation)
        self.main_output = keras.layers.Dense(1)
        self.aux_output = keras.layers.Dense(1)
    
    def call(self, inputs):
        input_a, input_b = inputs
        hidden1 = self.hidden1(input_b)
        hidden2 = self.hidden2(hidden1)
        concat = keras.layers.concatenate([input_a, hidden2])
        main_output = self.main_output(concat)
        aux_output = self.aux_output(hidden2)
        return main_output, aux_output

# %%
model = Mymodel()

# %%
model.compile(
    loss=['mse','mse'],
    loss_weights=[0.9, 0.1],
    optimizer='sgd'
)

# %%
history = model.fit([X_train_a,X_train_b], (y_train,y_train), epochs=30,
                   validation_data=([X_valid_a,X_valid_b], (y_valid,y_valid)))
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/30
# 11610/11610 [==============================] - 2s 199us/sample - loss: 1.2018 - output_1_loss: 1.0497 - output_2_loss: 2.5661 - val_loss: 0.6482 - val_output_1_loss: 0.5442 - val_output_2_loss: 1.5841
# Epoch 2/30
# 11610/11610 [==============================] - 1s 102us/sample - loss: 0.6055 - output_1_loss: 0.5102 - output_2_loss: 1.4628 - val_loss: 0.5717 - val_output_1_loss: 0.4842 - val_output_2_loss: 1.3596
# Epoch 3/30
# 11610/11610 [==============================] - 1s 98us/sample - loss: 0.5651 - output_1_loss: 0.4894 - output_2_loss: 1.2472 - val_loss: 0.5468 - val_output_1_loss: 0.4709 - val_output_2_loss: 1.2294
# Epoch 4/30
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.5332 - output_1_loss: 0.4651 - output_2_loss: 1.1485 - val_loss: 0.5241 - val_output_1_loss: 0.4564 - val_output_2_loss: 1.1330
# Epoch 5/30
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.5210 - output_1_loss: 0.4610 - output_2_loss: 1.0608 - val_loss: 0.5015 - val_output_1_loss: 0.4414 - val_output_2_loss: 1.0411
# Epoch 6/30
# 11610/11610 [==============================] - 1s 98us/sample - loss: 0.4971 - output_1_loss: 0.4435 - output_2_loss: 0.9778 - val_loss: 0.4837 - val_output_1_loss: 0.4309 - val_output_2_loss: 0.9579
# Epoch 7/30
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.4844 - output_1_loss: 0.4376 - output_2_loss: 0.9066 - val_loss: 0.4793 - val_output_1_loss: 0.4333 - val_output_2_loss: 0.8924
# Epoch 8/30
# 11610/11610 [==============================] - 1s 100us/sample - loss: 0.4686 - output_1_loss: 0.4283 - output_2_loss: 0.8320 - val_loss: 0.4654 - val_output_1_loss: 0.4261 - val_output_2_loss: 0.8182
# Epoch 9/30
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.4585 - output_1_loss: 0.4243 - output_2_loss: 0.7666 - val_loss: 0.4594 - val_output_1_loss: 0.4262 - val_output_2_loss: 0.7577
# Epoch 10/30
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.4466 - output_1_loss: 0.4169 - output_2_loss: 0.7146 - val_loss: 0.4464 - val_output_1_loss: 0.4162 - val_output_2_loss: 0.7177
# Epoch 11/30
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.4357 - output_1_loss: 0.4086 - output_2_loss: 0.6785 - val_loss: 0.4359 - val_output_1_loss: 0.4079 - val_output_2_loss: 0.6873
# Epoch 12/30
# 11610/11610 [==============================] - 1s 109us/sample - loss: 0.4241 - output_1_loss: 0.3990 - output_2_loss: 0.6484 - val_loss: 0.4212 - val_output_1_loss: 0.3947 - val_output_2_loss: 0.6596
# Epoch 13/30
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0.4172 - output_1_loss: 0.3942 - output_2_loss: 0.6260 - val_loss: 0.4140 - val_output_1_loss: 0.3893 - val_output_2_loss: 0.6361
# Epoch 14/30
# 11610/11610 [==============================] - 1s 98us/sample - loss: 0.4079 - output_1_loss: 0.3856 - output_2_loss: 0.6072 - val_loss: 0.4064 - val_output_1_loss: 0.3826 - val_output_2_loss: 0.6200
# Epoch 15/30
# 11610/11610 [==============================] - 1s 99us/sample - loss: 0

# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             multiple                  210
# _________________________________________________________________
# dense_14 (Dense)             multiple                  930
# _________________________________________________________________
# dense_15 (Dense)             multiple                  36
# _________________________________________________________________
# dense_16 (Dense)             multiple                  31
# =================================================================
# Total params: 1,207
# Trainable params: 1,207
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_func_two_inp_two_out.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# deep_input (InputLayer)         [(None, 6)]          0
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 30)           210         deep_input[0][0]
# __________________________________________________________________________________________________
# wide_input (InputLayer)         [(None, 5)]          0
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 30)           930         dense_11[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 35)           0           wide_input[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 1)            36          concatenate_3[0][0]
# __________________________________________________________________________________________________
# aux_output (Dense)              (None, 1)            31          dense_12[0][0]
# ==================================================================================================
# Total params: 1,207
# Trainable params: 1,207
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_func.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 30)           270         input_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 30)           930         dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 38)           0           input_2[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            39          concatenate_1[0][0]
# ==================================================================================================
# Total params: 1,239
# Trainable params: 1,239
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model_func.save('modelfunc.h5')

# %%
model_back = keras.models.load_model('modelfunc.h5')

# %%
model_back.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 30)           270         input_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 30)           930         dense_5[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 38)           0           input_2[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            39          concatenate_1[0][0]
# ==================================================================================================
# Total params: 1,239
# Trainable params: 1,239
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint('my_model.h5')

# %%
history = model_func.fit(X_train, y_train, epochs=10, callbacks=[checkpoint_cb])
# Out:
# Train on 11610 samples
# Epoch 1/10
# 11610/11610 [==============================] - 1s 71us/sample - loss: 0.3326
# Epoch 2/10
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3214
# Epoch 3/10
# 11610/11610 [==============================] - 1s 67us/sample - loss: 0.5090
# Epoch 4/10
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3392
# Epoch 5/10
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3282
# Epoch 6/10
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3210
# Epoch 7/10
# 11610/11610 [==============================] - 1s 69us/sample - loss: 0.3117
# Epoch 8/10
# 11610/11610 [==============================] - 1s 68us/sample - loss: 0.3173
# Epoch 9/10
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.3149
# Epoch 10/10
# 11610/11610 [==============================] - 1s 70us/sample - loss: 0.3129

# %%
checkpoint_cb = keras.callbacks.ModelCheckpoint('my_model.h5', save_best_only=True)

# %%
history = model_func.fit(X_train, y_train, epochs=10,
                         validation_data=(X_valid, y_valid),
                         callbacks=[checkpoint_cb])
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/10
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.3327 - val_loss: 0.3556
# Epoch 2/10
# 11610/11610 [==============================] - 1s 87us/sample - loss: 0.4668 - val_loss: 0.3157
# Epoch 3/10
# 11610/11610 [==============================] - 1s 84us/sample - loss: 0.3193 - val_loss: 0.3347
# Epoch 4/10
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.3104 - val_loss: 0.3091
# Epoch 5/10
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.3070 - val_loss: 0.3293
# Epoch 6/10
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.4248 - val_loss: 0.3205
# Epoch 7/10
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.3201 - val_loss: 0.3128
# Epoch 8/10
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.3043 - val_loss: 0.3368
# Epoch 9/10
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.4784 - val_loss: 0.3137
# Epoch 10/10
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.3071 - val_loss: 0.3443

# %%
model = keras.models.load_model('my_model.h5')

# %%
model.evaluate(X_test, y_test)
# Out:
# 5160/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================== ...
# 0.3107706524142923

# %%
# Using earlystopping 

early_stop = keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)

# %%
history = model.fit(X_train, y_train, epochs=100,
                    validation_data=(X_valid, y_valid),
                    callbacks=[checkpoint_cb, early_stop])
# Out:
# Train on 11610 samples, validate on 3870 samples
# Epoch 1/100
# 11610/11610 [==============================] - 1s 120us/sample - loss: 0.3088 - val_loss: 0.3170
# Epoch 2/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.3086 - val_loss: 0.3900
# Epoch 3/100
# 11610/11610 [==============================] - 1s 85us/sample - loss: 0.3199 - val_loss: 0.3837
# Epoch 4/100
# 11610/11610 [==============================] - 1s 86us/sample - loss: 0.3184 - val_loss: 0.3601
# Epoch 5/100
# 11610/11610 [==============================] - 1s 96us/sample - loss: 0.4822 - val_loss: 0.3144
# Epoch 6/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.3291 - val_loss: 0.3009
# Epoch 7/100
# 11610/11610 [==============================] - 1s 88us/sample - loss: 0.2999 - val_loss: 0.3313
# Epoch 8/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.3076 - val_loss: 0.3163
# Epoch 9/100
# 11610/11610 [==============================] - 1s 95us/sample - loss: 0.3015 - val_loss: 0.3387
# Epoch 10/100
# 11610/11610 [==============================] - 1s 98us/sample - loss: 0.3571 - val_loss: 0.3079
# Epoch 11/100
# 11610/11610 [==============================] - 1s 114us/sample - loss: 0.3084 - val_loss: 0.3085
# Epoch 12/100
# 11610/11610 [==============================] - 1s 92us/sample - loss: 0.2977 - val_loss: 0.3202
# Epoch 13/100
# 11610/11610 [==============================] - 1s 90us/sample - loss: 0.3508 - val_loss: 0.3053
# Epoch 14/100
# 11610/11610 [==============================] - 1s 87us/sample - loss: 0.3091 - val_loss: 0.3092
# Epoch 15/100
# 11610/11610 [==============================] - 1s 94us/sample - loss: 0.2980 - val_loss: 0.3026
# Epoch 16/100
# 11610/11610 [==============================] - 1s 91us/sample - loss: 0.2999 - val_loss: 0.3070
